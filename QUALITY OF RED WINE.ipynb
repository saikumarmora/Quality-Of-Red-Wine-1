# %% [markdown]
# PPT link : https://docs.google.com/presentation/d/1VtnYlDPWT0xCE1QQGTf0oCv4cQ9Mg9xQ/edit?usp=sharing&ouid=112259884849854760855&rtpof=true&sd=true

# %%
path="/content/drive/MyDrive/group 8 project/wine-red1.csv"

# %%
import pandas as pd
df=pd.read_csv(path)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   int64
#  6   total sulfur dioxide  1599 non-null   int64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(9), int64(3)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.875547             46.468418     0.996747
# std       0.047065            10.460434             32.895920     0.001887
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
ph = df['pH']
quality = df['quality']
plt.figure(figsize=(10, 6))
plt.bar(df.index, ph, alpha=0.5, label='pH', color='blue')
plt.bar(df.index, quality, alpha=0.5, label='Quality', color='red')
plt.xlabel('Sample')
plt.ylabel('Value')
plt.title('Comparison of pH and Quality for Red Wine')
plt.legend(loc='upper left')
plt.show()

# %%
columns_of_interest = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar']
selected_data = df[columns_of_interest]
plt.figure(figsize=(12, 8))
for i, column in enumerate(selected_data.columns, 1):
    plt.subplot(2, 2, i)
    plt.hist(selected_data[column], bins=20, edgecolor='black', color='skyblue')
    plt.xlabel(column)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
columns_of_interest = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar','pH', 'quality']
corr_matrix = df[columns_of_interest].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
columns_of_interest = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'pH', 'quality']
plt.figure(figsize=(12, 8))
for i, col in enumerate(columns_of_interest, 1):
    plt.subplot(2, 3, i)
    plt.scatter(df[col], df['quality'], alpha=0.5)
    plt.xlabel(col)
    plt.ylabel('Quality')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Boxplot of the quality scores by alcohol content**

# %%
sns.boxplot(x='quality', y='alcohol', data=df)
plt.xlabel('Quality Score')
plt.ylabel('Alcohol Content')
plt.title('Quality Scores by Alcohol Content')
# Out:
# Text(0.5, 1.0, 'Quality Scores by Alcohol\xa0Content')

# %% [markdown]
# **Violinplot of the quality scores by residual sugar content**

# %%
sns.violinplot(x='quality', y='residual sugar', data=df)
plt.xlabel('Quality Score')
plt.ylabel('Residual Sugar Content')
plt.title('Quality Scores by Residual Sugar Content')
# Out:
# Text(0.5, 1.0, 'Quality Scores by Residual\xa0Sugar\xa0Content')

# %% [markdown]
# **Barplot of the average citric acid by quality score**

# %%
sns.barplot(x='quality', y='citric acid', data=df, ci=None)
plt.xlabel('Quality Score')
plt.ylabel('Average Citric Acid')
plt.title('Average Citric Acid by Quality Score')
# Out:
# <ipython-input-15-7980f5094e71>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='quality', y='citric acid', data=df, ci=None)
# Text(0.5, 1.0, 'Average Citric Acid by\xa0Quality\xa0Score')

# %%
import numpy as np
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %% [markdown]
# **linear regression**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import  r2_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Coefficients:', lr.coef_)
print('Intercept:', lr.intercept_)
print('Mean Squared Error:',mse)
r2 = r2_score(y_test, y_pred)
print('R-Squared:%.2f' % r2)
# Out:
# Coefficients: [-2.88267183e-02 -1.00057436e+00 -9.78232772e-02 -3.85148115e-03
#  -2.21114548e+00  4.73823652e-03 -3.71882562e-03  2.26091684e+01
#  -7.98967349e-01  8.54566410e-01  3.06156585e-01]
# Intercept: -16.910989360981965
# Mean Squared Error: 0.43100451018603236
# R-Squared:0.39

# %%
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %% [markdown]
# **svm**

# %%
from sklearn.svm import SVR
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
sv = SVR(kernel='linear')
sv.fit(X_train, y_train)
y_pred = sv.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Coefficients:', sv.coef_)
print('Intercept:', sv.intercept_)
print('Mean Squared Error:',mse)
r2 = r2_score(y_test, y_pred)
print('R-Squared:%.2f' % r2)
# Out:
# Coefficients: [[ 0.02755541 -0.82075275 -0.13987282  0.02693548 -1.37449385  0.00381977
#   -0.00335934 -0.02264115 -0.38878052  0.8137441   0.33681901]]
# Intercept: [3.25652016]
# Mean Squared Error: 0.42528023650563085
# R-Squared:0.40

# %% [markdown]
# **knn**

# %%
from sklearn.neighbors import KNeighborsRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
pr = KNeighborsRegressor(n_neighbors=5)
pr.fit(X_train, y_train)
y_pred = pr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:',mse)
r2 = r2_score(y_test, y_pred)
print('R-Squared:%.2f' % r2)
# Out:
# Mean Squared Error: 0.6754411764705882
# R-Squared:0.05

# %% [markdown]
#  decision **tree**

# %%
from sklearn.tree import DecisionTreeRegressor
X_train, X_test, y_train, y_test = train_test_split (X,y ,test_size=0.20, random_state=42)
dt = DecisionTreeRegressor(max_depth=7)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:',mse)
r2 = r2_score(y_test, y_pred)
print('R-Squared:%.2f' % r2)
# Out:
# Mean Squared Error: 0.5108442712097873
# R-Squared:0.28

# %% [markdown]
# ***Random forest***

# %%
from sklearn.ensemble import RandomForestRegressor
X_train, X_test, y_train, y_test = train_test_split(X,y ,test_size=0.20, random_state=42)
rf = RandomForestRegressor(n_estimators=100, max_depth=7)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:',mse)
r2 = r2_score(y_test, y_pred)
print('R-Squared:%.2f' % r2)
# Out:
# Mean Squared Error: 0.3785758745955612
# R-Squared:0.47

# %% [markdown]
# **ADA Boost**

# %%
from sklearn.ensemble import AdaBoostRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
dtr = DecisionTreeRegressor(max_depth=1)
abr = AdaBoostRegressor(n_estimators=100, learning_rate=0.01, base_estimator=dtr)
abr.fit(X_train, y_train)
y_pred = abr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:',mse)
r2 = r2_score(y_test, y_pred)
print('R-Squared:%.2f' % r2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Mean Squared Error: 0.5812211018128202
# R-Squared:0.18

# %% [markdown]
# **Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
gbr = GradientBoostingRegressor(n_estimators=500, learning_rate=0.01, max_depth=3)
gbr.fit(X_train, y_train)
y_pred = gbr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:',mse)
r2 = r2_score(y_test, y_pred)
print('R-Squared:%.2f' % r2)
# Out:
# Mean Squared Error: 0.38270485774194785
# R-Squared:0.46

# %% [markdown]
# **XG Boost**

# %%
import xgboost as xgb
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
xgbr = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)
xgbr.fit(X_train, y_train)
y_pred = xgbr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:',mse)
r2 = r2_score(y_test, y_pred)
print('R-Squared:%.2f' % r2)
# Out:
# Mean Squared Error: 0.3753827151294716
# R-Squared:0.47
